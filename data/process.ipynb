# %%
import pandas as pd
import geopandas as gpd

# %%
gpd.read_file('business_districts_enriched.geojson')['stickinessScore'].describe()
# Out:
# count    132.000000
# mean      53.553939
# std        6.237723
# min       38.800000
# 25%       49.297500
# 50%       52.995000
# 75%       56.755000
# max       69.930000
# Name: stickinessScore, dtype: float64
